# %% [markdown]
# <a href="https://colab.research.google.com/github/SaulHuitzil/Ejemplo-Notebooks-Colaboratory-Anidados/blob/main/Ejemplo_de_Uso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install import-ipynb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.3 MB/s eta 0:00:00
# ...

# %%
# !wget https://raw.githubusercontent.com/SaulHuitzil/Ejemplo-Notebooks-Colaboratory-Anidados/refs/heads/main/TestShj01.ipynb
# !wget https://raw.githubusercontent.com/SaulHuitzil/Ejemplo-Notebooks-Colaboratory-Anidados/refs/heads/main/TestShj02.ipynb
# Out:
# --2025-01-24 01:06:11--  https://raw.githubusercontent.com/SaulHuitzil/Ejemplo-Notebooks-Colaboratory-Anidados/refs/heads/main/TestShj01.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1714 (1.7K) [text/plain]
# Saving to: ‘TestShj01.ipynb’
#
# TestShj01.ipynb     100%[===================>]   1.67K  --.-KB/s    in 0s
#
# 2025-01-24 01:06:11 (25.2 MB/s) - ‘TestShj01.ipynb’ saved [1714/1714]
#
# --2025-01-24 01:06:12--  https://raw.githubusercontent.com/SaulHuitzil/Ejemplo-Notebooks-Colaboratory-Anidados/refs/heads/main/TestShj02.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# ...

# %%
import import_ipynb
import TestShj02  # Asegúrate de haber descargado TestShj02.ipynb previamente

# Usa la clase extendida desde TestShj02
mi_objeto = TestShj02.MiClaseExtendida("Saúl")
print(mi_objeto.saludar())      # Método de TestShj01
print(mi_objeto.despedirse())  # Método extendido en TestShj02
# Out:
# Hola, Saúl!
# Adiós, Saúl!

# %%
# !wget https://raw.githubusercontent.com/SaulHuitzil/Boolean-Networks/refs/heads/main/Boolean_Network.ipynb
# Out:
# --2025-01-24 00:41:42--  https://raw.githubusercontent.com/SaulHuitzil/Boolean-Networks/refs/heads/main/Boolean_Network.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9629 (9.4K) [text/plain]
# Saving to: ‘Boolean_Network.ipynb’
#
# Boolean_Network.ipy 100%[===================>]   9.40K  --.-KB/s    in 0s
#
# 2025-01-24 00:41:42 (73.3 MB/s) - ‘Boolean_Network.ipynb’ saved [9629/9629]

# %%
import import_ipynb
import Boolean_Network as BN

# %%
red = BN.Red()

# %%
red.CrearRed(100, 2)

# %%
estado = "0101110000010111000001011100000101110000010111000001011100000101110000010111000001011100000101110000"

# %%
for i in range(100):
  estado = red.Actualizar(estado)
  print(estado)
# Out:
# 1011001010101001001010100100000100000000001001001100001011101001111111100111011101101100111010100101
# 1010011010001010110011011101001110001000101001000100010110110000110101000111010011000011111011000110
# 1010001010001110111111010000111010001000001011011100110011111000101101100111110111101010111011000011
# 1010111010000110111101110010110010001000101111010100110011100001111111110111111111100010110011011010
# 1010101010000000111101111011110110001000101101000101000111001000101111100111111011100010110000011010
# 1011001010000100010111011011010110001000101101001101100011101000100111010111111011000010110001001010
# 1010101010001100011111011011110110101000001101001101110111111000110101110111111011001010110001001010
# 1010111010001100010111010011111010101000101101000101111111111011100111000111111011101010110011001010
# 1010111010001000111111010011100010001000001111010101011111101010110101110111111011000010110000010010
# ...
